# %%
using RData
fulldata = load("data.RData");
data = fulldata["data"];

# %%
data
# Out:
# 6418797×11 DataFrames.DataFrame
# │ Row     │ Primary_Type          │ Description                    │
# ├─────────┼───────────────────────┼────────────────────────────────┤
# │ 1       │ "CRIMINAL TRESPASS"   │ "TO LAND"                      │
# │ 2       │ "NARCOTICS"           │ "POSS: CANNABIS 30GMS OR LESS" │
# │ 3       │ "THEFT"               │ "OVER \$500"                    │
# │ 4       │ "THEFT"               │ "\$500 AND UNDER"               │
# │ 5       │ "MOTOR VEHICLE THEFT" │ "AUTOMOBILE"                   │
# │ 6       │ "NARCOTICS"           │ "POSS: CRACK"                  │
# │ 7       │ "CRIMINAL DAMAGE"     │ "TO PROPERTY"                  │
# │ 8       │ "PROSTITUTION"        │ "SOLICIT FOR PROSTITUTE"       │
# │ 9       │ "CRIMINAL DAMAGE"     │ "TO STATE SUP PROP"            │
# │ 10      │ "OTHER OFFENSE"       │ "OBSCENE TELEPHONE CALLS"      │
# │ 11      │ "NARCOTICS"           │ "POSS: CRACK"                  │
# ⋮
# │ 6418786 │ "BURGLARY"            │ "FORCIBLE ENTRY"               │
# │ 6418787 │ "OTHER OFFENSE"       │ "OTHER VEHICLE OFFENSE"        │
# │ 6418788 │ "THEFT"               │ "FROM BUILDING"                │
# │ 6418789 │ "DECEPTIVE PRACTICE"  │ "CREDIT CARD FRAUD"            │
# │ 6418790 │ "BURGLARY"            │ "FORCIBLE ENTRY"               │
# │ 6418791 │ "OTHER OFFENSE"       │ "OTHER VEHICLE OFFENSE"        │
# │ 6418792 │ "THEFT"               │ "\$500 AND UNDER"               │
# │ 6418793 │ "BURGLARY"            │ "FORCIBLE ENTRY"               │
# │ 6418794 │ "BURGLARY"            │ "UNLAWFUL ENTRY"               │
# │ 6418795 │ "THEFT"               │ "FROM BUILDING"                │
# │ 6418796 │ "THEFT"               │ "\$500 AND UNDER"               │
# │ 6418797 │ "OBSCENITY"           │ "OBSCENITY"                    │
#
# │ Row     │ Location_Description                │ District │ Community_Area │
# ├─────────┼─────────────────────────────────────┼──────────┼────────────────┤
# │ 1       │ "PARKING LOT/GARAGE(NON.RESID.)"    │ 8        │ 66             │
# │ 2       │ "STREET"                            │ 7        │ 68             │
# │ 3       │ "CHURCH/SYNAGOGUE/PLACE OF WORSHIP" │ 11       │ 23             │
# │ 4       │ "STREET"                            │ 6        │ 44             │
# │ 5       │ "STREET"                            │ 7        │ 67             │
# │ 6       │ "SIDEWALK"                          │ 10       │ 29             │
# │ 7       │ "SCHOOL, PUBLIC, BUILDING"          │ 6        │ 71             │
# │ 8       │ "STREET"                            │ 4        │ 46             │
# │ 9       │ "SCHOOL, PUBLIC, BUILDING"          │ 22       │ 49             │
# │ 10      │ "RESIDENCE"                         │ 24       │ 77             │
# │ 11      │ "STREET"                            │ 22       │ 73             │
# ⋮
# │ 6418786 │ "COMMERCIAL / BUSINESS OFFICE"      │ 18       │ 8              │
# │ 6418787 │ "STREET"                            │ 11       │ 27             │
# │ 6418788 │ "RESIDENCE"                         │ 3        │ 43             │
# │ 6418789 │ "OTHER"                             │ 24       │ 1              │
# │ 6418790 │ "COMMERCIAL / BUSINESS OFFICE"      │ 18       │ 8              │
# │ 6418791 │ "STREET"                            │ 5        │ 53             │
# │ 6418792 │ "STREET"                            │ 25       │ 23             │
# │ 6418793 │ "RESIDENCE"                         │ 14       │ 22             │
# │ 6418794 │ "FACTORY/MANUFACTURING BUILDING"    │ 11       │ 28             │
# │ 6418795 │ "RESIDENCE PORCH/HALLWAY"           │ 24       │ 2              │
# │ 6418796 │ "STREET"                            │ 17       │ 16             │
# │ 6418797 │ "APARTMENT"                         │ 2        │ 40             │
#
# │ Row     │ X_Coordinate │ Y_Coordinate │ Year │ Latitude │ Longitude │
# ├─────────┼──────────────┼──────────────┼──────┼──────────┼───────────┤
# │ 1       │ 1161441      │ 1863309      │ 2006 │ 41.7806  │ -87.6837  │
# │ 2       │ 1174958      │ 1866097      │ 2006 │ 41.788   │ -87.634   │
# │ 3       │ 1154100      │ 1907414      │ 2006 │ 41.9018  │ -87.7094  │
# │ 4       │ 1184622      │ 1851863      │ 2006 │ 41.7487  │ -87.599   │
# │ 5       │ 1164792      │ 1861919      │ 2006 │ 41.7767  │ -87.6714  │
# │ 6       │ 1155120      │ 1893275      │ 2006 │ 41.863   │ -87.706   │
# │ 7       │ 1170069      │ 1850820      │ 2006 │ 41.7461  │ -87.6524  │
# │ 8       │ 1197222      │ 1852411      │ 2006 │ 41.7499  │ -87.5529  │
# │ 9       │ 1174313      │ 1830380      │ 2005 │ 41.69    │ -87.6375  │
# │ 10      │ 1165597      │ 1941287      │ 2006 │ 41.9945  │ -87.6662  │
# │ 11      │ 1168597      │ 1844242      │ 2006 │ 41.7281  │ -87.658   │
# ⋮
# │ 6418786 │ 1175002      │ 1905476      │ 2017 │ 41.896   │ -87.6327  │
# │ 6418787 │ 1158660      │ 1899914      │ 2017 │ 41.8811  │ -87.6929  │
# │ 6418788 │ 1190658      │ 1857619      │ 2017 │ 41.7643  │ -87.5767  │
# │ 6418789 │ 1167277      │ 1942715      │ 2017 │ 41.9984  │ -87.66    │
# │ 6418790 │ 1175002      │ 1905476      │ 2017 │ 41.896   │ -87.6327  │
# │ 6418791 │ 1175374      │ 1823341      │ 2017 │ 41.6706  │ -87.6338  │
# │ 6418792 │ 1147430      │ 1909910      │ 2017 │ 41.9088  │ -87.7339  │
# │ 6418793 │ 1158303      │ 1912521      │ 2017 │ 41.9157  │ -87.6938  │
# │ 6418794 │ 1159680      │ 1895957      │ 2017 │ 41.8702  │ -87.6892  │
# │ 6418795 │ 1158797      │ 1943379      │ 2017 │ 42.0004  │ -87.6912  │
# │ 6418796 │ 1156622      │ 1927972      │ 2017 │ 41.9581  │ -87.6996  │
# │ 6418797 │ 1179798      │ 1870997      │ 2017 │ 41.8013  │ -87.6161  │
#
# │ Row     │ Location                        │
# ├─────────┼─────────────────────────────────┤
# │ 1       │ "(41.780595495, -87.68367553)"  │
# │ 2       │ "(41.787955143, -87.634036744)" │
# │ 3       │ "(41.901774026, -87.709414574)" │
# │ 4       │ "(41.748674558, -87.599048654)" │
# │ 5       │ "(41.776711023, -87.671429342)" │
# │ 6       │ "(41.86295478, -87.706047579)"  │
# │ 7       │ "(41.746140855, -87.652406156)" │
# │ 8       │ "(41.749873967, -87.552860394)" │
# │ 9       │ "(41.68995741, -87.637460623)"  │
# │ 10      │ "(41.99448592, -87.666216312)"  │
# │ 11      │ "(41.728121719, -87.657989027)" │
# ⋮
# │ 6418786 │ "(41.896013242, -87.632697553)" │
# │ 6418787 │ "(41.881101134, -87.692870716)" │
# │ 6418788 │ "(41.764326034, -87.576745423)" │
# │ 6418789 │ "(41.998368301, -87.65999524)"  │
# │ 6418790 │ "(41.896013242, -87.632697553)" │
# │ 6418791 │ "(41.670617706, -87.633785524)" │
# │ 6418792 │ "(41.90875381, -87.733850436)"  │
# │ 6418793 │ "(41.915703128, -87.693836539)" │
# │ 6418794 │ "(41.870221805, -87.68923437)"  │
# │ 6418795 │ "(42.000369085, -87.691172056)" │
# │ 6418796 │ "(41.95813599, -87.699592782)"  │
# │ 6418797 │ "(41.801291795, -87.616140652)" │

# %%
fulldata
# Out:
# Dict{String,Any} with 6 entries:
#   "lat"          => [41.7806, 41.788, 41.9018, 41.7487, 41.7767, 41.863, 41.746…
#   ".Random.seed" => Int32[403, 10, -1723298115, 1733085495, -1933062690, -19910…
#   "na_ind"       => Int32[125, 1333, 1549, 1613, 1790, 2307, 3958, 3973, 4389, …
#   "data"         => 6418797×11 DataFrames.DataFrame…
#   "lon"          => [-87.6837, -87.634, -87.7094, -87.599, -87.6714, -87.706, -…
#   "outlier_ind"  => Int32[825765, 908492, 910834, 940775, 962488, 965468, 98447…

# %%
a = Array{Float64,1}(data[:,6])/10000;
b = Array{Float64,1}(data[:,7])/10000;
ind = find((a .> 112) .& (a .< 120.05) .& (b .> 181) .& (b .< 195.05));
a = a[ind]; b = b[ind];

# %%
scatter(a[1:40000],b[1:40000], s = 0.1)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x12c36ff90>)
# PyObject <matplotlib.collections.PathCollection object at 0x13d15a310>

# %%
a = floor.(Int,a*20);
b = floor.(Int,b*20);
scatter(a[1:40000],b[1:40000], s = 0.1)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x14d278050>)
# PyObject <matplotlib.collections.PathCollection object at 0x12b676b10>

# %%
x = 2240:2400; y = 3620:3900
X = repeat(x, inner = length(y))
Y = repeat(y, outer = length(x))
z = zeros(length(X))
for i = 1:length(a)
    ind = (a[i] - 2240) * length(y) + (b[i] - 3619);
    z[ind] += 1;
    if rem(i,1000000) == 0
        println(Int(i/1000000))
    end
end
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
pcolormesh(reshape(z,length(y),length(x)), cmap = "PuRd")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x170ae8190>)
# PyObject <matplotlib.collections.QuadMesh object at 0x173691950>
