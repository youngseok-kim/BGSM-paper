# %%
using ExcelReaders, PyPlot

# %%
using

# %%
data1 = readxlsheet("biclust1.xls", "DatasetB_675gene");
data2 = readxlsheet("biclust2.xls", "DatasetA_12600gene");

# %%
X = Array{Float64,2}(data1[2:end,2:end]);
n1,p1 = size(X);
X = X - repmat(mean(X,1),n1,1);
X = X ./ sqrt.(sum(X.^2,2));

# %%
pcolormesh(X)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x13ab9e390>)
# PyObject <matplotlib.collections.QuadMesh object at 0x13abf9310>

# %%
Y = Array{Float64,2}(data2[2:end,2:end]);
n2,p2 = size(y);
Y = Y - repmat(mean(Y,1),n2,1);
Y = Y ./ sqrt.(sum(Y.^2,2));
